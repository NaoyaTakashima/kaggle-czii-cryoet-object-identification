# %%
import torch
import gc
import wandb

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
PROJECT_ID = 'L'

BASE_DIR = f"/kaggle/project/{PROJECT_ID}"

# %%
# %cd {BASE_DIR}
# Out:
# /kaggle/project/L

# %%
data_dir_x = '/kaggle/input/numpy-dataset'
data_dir_y = '/kaggle/input/numpy-dataset-heatmap-all-20'

exp_nos = ['006']
# select_folds = [1, 2, 3, 4]
# select_folds = [2, 3, 4]
# select_folds = [3, 4, 5, 6]
select_folds = [1]
# select_folds = [2]
# select_folds = [1, 3, 4]

model = 'Unet'

batch_size_train = 2
batch_size_valid = 16
num_workers = 8
epoch = 50 * 4
lr = 0.001

num_samples = int(16)
spatial_size = int(48)
patch_size = int(184)

# alpha = 0.7
# beta = 0.3

# %%
for i, exp_no in enumerate(exp_nos):
    project = f'CZII-{PROJECT_ID}'
    output_dir = f'{BASE_DIR}/output'

    for valid_fold in select_folds:
        exp_name = f'{exp_no}-{valid_fold}'
        split = f'fold_{valid_fold}'

        # !./run_with_retries.sh "python -m run.train\
            project=$project\
            exp_no=$exp_no\
            exp_name=$exp_name\
            dir.data_dir_x=$data_dir_x\
            dir.data_dir_y=$data_dir_y\
            dir.output_dir=$output_dir\
            split=$split\
            model=$model\
            batch_size_train=$batch_size_train\
            batch_size_valid=$batch_size_valid\
            num_samples=$num_samples\
            spatial_size=$spatial_size\
            patch_size=$patch_size\
            num_workers=$num_workers\
            epoch=$epoch\
            optimizer.lr=$lr"

        wandb.finish()

        torch.cuda.empty_cache()
        gc.collect()
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.24 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 2025-01-07 00:43:04.455762: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-07 00:43:04.655878: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
