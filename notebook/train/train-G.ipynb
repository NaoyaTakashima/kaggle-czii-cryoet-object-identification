# %%
import torch
import gc
import wandb

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
PROJECT_ID = 'G'

BASE_DIR = f"/home/naoya/kaggle/czii/project/{PROJECT_ID}"

# %%
# %cd {BASE_DIR}
# Out:
# /home/naoya/kaggle/czii/project/G
# /home/naoya/kaggle/czii/.venv/lib/python3.12/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
data_dir = '/home/naoya/kaggle/czii/input/numpy-dataset'

exp_nos = ['003']
# select_folds = [1, 2, 3, 4]
# select_folds = [2, 3, 4]
# select_folds = [3, 4, 5, 6]
# select_folds = [2]
select_folds = [1, 3, 4]

model = 'Unet'
batch_size_train = 2
batch_size_valid = 16
num_workers = 8
epoch = 50 * 4
lr = 0.001

num_samples = int(16)
spatial_size = int(96)
patch_size = int(96)

# alpha = 0.7
# beta = 0.3

# %%
for i, exp_no in enumerate(exp_nos):
    project = f'CZII-{PROJECT_ID}'
    output_dir = f'{BASE_DIR}/output'

    for valid_fold in select_folds:
        exp_name = f'{exp_no}-{valid_fold}'
        split = f'fold_{valid_fold}'

        # !./run_with_retries.sh "python -m run.train\
            project=$project\
            exp_no=$exp_no\
            exp_name=$exp_name\
            dir.data_dir=$data_dir\
            dir.output_dir=$output_dir\
            split=$split\
            model=$model\
            batch_size_train=$batch_size_train\
            batch_size_valid=$batch_size_valid\
            num_samples=$num_samples\
            spatial_size=$spatial_size\
            patch_size=$patch_size\
            num_workers=$num_workers\
            epoch=$epoch\
            optimizer.lr=$lr"

        wandb.finish()

        torch.cuda.empty_cache()
        gc.collect()
# Out:
# /home/naoya/kaggle/czii/.venv/lib/python3.12/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.22 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# [2024-12-16 03:42:51,142][train.py][INFO] - Set Up DataModule
# Loading dataset: 100%|████████████████████████████| 4/4 [00:00<00:00, 14.77it/s]
# Loading dataset: 100%|█████████████████████████| 98/98 [00:00<00:00, 280.01it/s]
# Loading dataset: 100%|████████████████████████████| 4/4 [00:00<00:00, 14.87it/s]
# Loading dataset: 100%|████████████████████████████| 4/4 [00:00<00:00, 15.02it/s]
# /home/naoya/kaggle/czii/.venv/lib/python3.12/site-packages/lightning_fabric/connector.py:571: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: naoya-takashima. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path output/wandb_logs/wandb/ wasn't writable, using system temp directory.
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /tmp/wandb/run-20241216_034310-7mo0f3hs
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 003-1
# wandb: ⭐️ View project at https://wandb.ai/naoya-takashima/CZII-G
# wandb: 🚀 View run at https://wandb.ai/naoya-takashima/CZII-G/runs/7mo0f3hs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name               ┃ Type             ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ model              │ Unet             │  1.1 M │ train │
# │ 1 │ model.model        │ UNet             │  1.1 M │ train │
# │ 2 │ model.loss_fn_tv   │ TverskyLoss      │      0 │ train │
# │ 3 │ model.loss_fn_dice │ DiceLoss         │      0 │ train │
# │ 4 │ model.loss_fn_ce   │ CrossEntropyLoss │      0 │ train │
# └───┴────────────────────┴──────────────────┴────────┴───────┘
# Trainable params: 1.1 M
# Non-trainable params: 0
# Total params: 1.1 M
# Total estimated model params size (MB): 4
# Modules in train mode: 91
# Modules in eval mode: 0
# Epoch 0: 100%|██████████████████████| 24/24 [00:12<00:00,  1.94it/s, v_num=f3hs]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.36it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.36it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.69it/s]Saved best model inf -> 0.8709641780172076
#
# Epoch 0: 100%|█| 24/24 [00:13<00:00,  1.84it/s, v_num=f3hs, val_loss=0.871, traiEpoch 0, global step 24: 'val_loss' reached 0.87150 (best 0.87150), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=0-step=24.ckpt' as top 1
# Epoch 1: 100%|█| 24/24 [00:11<00:00,  2.06it/s, v_num=f3hs, val_loss=0.871, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.42it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.39it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.44it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.49it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.20it/s]Saved best model 0.8709641780172076 -> 0.835453348500388
#
# Epoch 1: 100%|█| 24/24 [00:12<00:00,  1.97it/s, v_num=f3hs, val_loss=0.836, traiEpoch 1, global step 48: 'val_loss' reached 0.83564 (best 0.83564), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=1-step=48.ckpt' as top 1
# Epoch 2: 100%|█| 24/24 [00:13<00:00,  1.77it/s, v_num=f3hs, val_loss=0.836, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.43it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.18it/s]Saved best model 0.835453348500388 -> 0.8338230763162885
#
# Epoch 2: 100%|█| 24/24 [00:14<00:00,  1.66it/s, v_num=f3hs, val_loss=0.834, traiEpoch 2, global step 72: 'val_loss' reached 0.83441 (best 0.83441), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=2-step=72.ckpt' as top 1
# Epoch 3: 100%|█| 24/24 [00:14<00:00,  1.67it/s, v_num=f3hs, val_loss=0.834, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.31it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.13it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.22it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.18it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.20it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.82it/s]Saved best model 0.8338230763162885 -> 0.8259687764304025
#
# Epoch 3: 100%|█| 24/24 [00:15<00:00,  1.57it/s, v_num=f3hs, val_loss=0.827, traiEpoch 3, global step 96: 'val_loss' reached 0.82702 (best 0.82702), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=3-step=96.ckpt' as top 1
# Epoch 4: 100%|█| 24/24 [00:13<00:00,  1.78it/s, v_num=f3hs, val_loss=0.827, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.35it/s]Saved best model 0.8259687764304025 -> 0.8228269389697483
#
# Epoch 4: 100%|█| 24/24 [00:15<00:00,  1.59it/s, v_num=f3hs, val_loss=0.824, traiEpoch 4, global step 120: 'val_loss' reached 0.82406 (best 0.82406), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=4-step=120.ckpt' as top 1
# Epoch 5: 100%|█| 24/24 [00:13<00:00,  1.77it/s, v_num=f3hs, val_loss=0.824, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.50it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.41it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.49it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.21it/s]Saved best model 0.8228269389697483 -> 0.8206274424280439
#
# Epoch 5: 100%|█| 24/24 [00:14<00:00,  1.63it/s, v_num=f3hs, val_loss=0.822, traiEpoch 5, global step 144: 'val_loss' reached 0.82200 (best 0.82200), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=5-step=144.ckpt' as top 1
# Epoch 6: 100%|█| 24/24 [00:13<00:00,  1.84it/s, v_num=f3hs, val_loss=0.822, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.50it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.19it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.32it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.30it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.34it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.21it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.50it/s]Saved best model 0.8206274424280439 -> 0.8146613410540989
#
# Epoch 6: 100%|█| 24/24 [00:14<00:00,  1.69it/s, v_num=f3hs, val_loss=0.816, traiEpoch 6, global step 168: 'val_loss' reached 0.81626 (best 0.81626), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=6-step=168.ckpt' as top 1
# Epoch 7: 100%|█| 24/24 [00:12<00:00,  1.96it/s, v_num=f3hs, val_loss=0.816, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.06it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.62it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.25it/s]Saved best model 0.8146613410540989 -> 0.812801889010838
#
# Epoch 7: 100%|█| 24/24 [00:13<00:00,  1.82it/s, v_num=f3hs, val_loss=0.815, traiEpoch 7, global step 192: 'val_loss' reached 0.81506 (best 0.81506), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=7-step=192.ckpt' as top 1
# Epoch 8: 100%|█| 24/24 [00:11<00:00,  2.00it/s, v_num=f3hs, val_loss=0.815, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.02it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.33it/s]Saved best model 0.812801889010838 -> 0.8118344800812858
#
# Epoch 8: 100%|█| 24/24 [00:12<00:00,  1.85it/s, v_num=f3hs, val_loss=0.814, traiEpoch 8, global step 216: 'val_loss' reached 0.81412 (best 0.81412), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=8-step=216.ckpt' as top 1
# Epoch 9: 100%|█| 24/24 [00:11<00:00,  2.03it/s, v_num=f3hs, val_loss=0.814, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.07it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.44it/s]Saved best model 0.8118344800812858 -> 0.8072798422404698
#
# Epoch 9: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=f3hs, val_loss=0.810, traiEpoch 9, global step 240: 'val_loss' reached 0.80988 (best 0.80988), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=9-step=240.ckpt' as top 1
# Epoch 10: 100%|█| 24/24 [00:11<00:00,  2.02it/s, v_num=f3hs, val_loss=0.810, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.24it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.30it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.18it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.27it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.93it/s]
# Epoch 10: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=f3hs, val_loss=0.812, traEpoch 10, global step 264: 'val_loss' was not in top 1
# Epoch 11: 100%|█| 24/24 [00:15<00:00,  1.55it/s, v_num=f3hs, val_loss=0.812, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.75it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.34it/s]Saved best model 0.8072798422404698 -> 0.80189939056124
#
# Epoch 11: 100%|█| 24/24 [00:16<00:00,  1.46it/s, v_num=f3hs, val_loss=0.803, traEpoch 11, global step 288: 'val_loss' reached 0.80308 (best 0.80308), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=11-step=288.ckpt' as top 1
# Epoch 12: 100%|█| 24/24 [00:12<00:00,  1.97it/s, v_num=f3hs, val_loss=0.803, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.55it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.44it/s]Saved best model 0.80189939056124 -> 0.8012345688683646
#
# Epoch 12: 100%|█| 24/24 [00:13<00:00,  1.83it/s, v_num=f3hs, val_loss=0.804, traEpoch 12, global step 312: 'val_loss' was not in top 1
# Epoch 13: 100%|█| 24/24 [00:11<00:00,  2.05it/s, v_num=f3hs, val_loss=0.804, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.14it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.36it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.33it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.07it/s]Saved best model 0.8012345688683646 -> 0.7989408714430672
#
# Epoch 13: 100%|█| 24/24 [00:12<00:00,  1.90it/s, v_num=f3hs, val_loss=0.800, traEpoch 13, global step 336: 'val_loss' reached 0.80038 (best 0.80038), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=13-step=336.ckpt' as top 1
# Epoch 14: 100%|█| 24/24 [00:11<00:00,  2.03it/s, v_num=f3hs, val_loss=0.800, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.11it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.80it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.48it/s]
# Epoch 14: 100%|█| 24/24 [00:12<00:00,  1.88it/s, v_num=f3hs, val_loss=0.804, traEpoch 14, global step 360: 'val_loss' was not in top 1
# Epoch 15: 100%|█| 24/24 [00:11<00:00,  2.06it/s, v_num=f3hs, val_loss=0.804, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.20it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.21it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.13it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.17it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.12it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.41it/s]Saved best model 0.7989408714430672 -> 0.7972834195409503
#
# Epoch 15: 100%|█| 24/24 [00:12<00:00,  1.89it/s, v_num=f3hs, val_loss=0.802, traEpoch 15, global step 384: 'val_loss' was not in top 1
# Epoch 16: 100%|█| 24/24 [00:11<00:00,  2.12it/s, v_num=f3hs, val_loss=0.802, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.75it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.91it/s]Saved best model 0.7972834195409503 -> 0.7905238611357552
#
# Epoch 16: 100%|█| 24/24 [00:12<00:00,  1.95it/s, v_num=f3hs, val_loss=0.794, traEpoch 16, global step 408: 'val_loss' reached 0.79417 (best 0.79417), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=16-step=408.ckpt' as top 1
# Epoch 17: 100%|█| 24/24 [00:11<00:00,  2.08it/s, v_num=f3hs, val_loss=0.794, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.40it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.26it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.25it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.26it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.14it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.21it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.42it/s]
# Epoch 17: 100%|█| 24/24 [00:12<00:00,  1.91it/s, v_num=f3hs, val_loss=0.795, traEpoch 17, global step 432: 'val_loss' was not in top 1
# Epoch 18: 100%|█| 24/24 [00:11<00:00,  2.06it/s, v_num=f3hs, val_loss=0.795, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.28it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.32it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.14it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.13it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.14it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.42it/s]
# Epoch 18: 100%|█| 24/24 [00:12<00:00,  1.90it/s, v_num=f3hs, val_loss=0.804, traEpoch 18, global step 456: 'val_loss' was not in top 1
# Epoch 19: 100%|█| 24/24 [00:13<00:00,  1.74it/s, v_num=f3hs, val_loss=0.804, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.20it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.52it/s]Saved best model 0.7905238611357552 -> 0.7890834552901131
#
# Epoch 19: 100%|█| 24/24 [00:14<00:00,  1.63it/s, v_num=f3hs, val_loss=0.794, traEpoch 19, global step 480: 'val_loss' was not in top 1
# Epoch 20: 100%|█| 24/24 [00:11<00:00,  2.13it/s, v_num=f3hs, val_loss=0.794, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.44it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.81it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.51it/s]Saved best model 0.7890834552901131 -> 0.7831796407699585
#
# Epoch 20: 100%|█| 24/24 [00:12<00:00,  1.98it/s, v_num=f3hs, val_loss=0.791, traEpoch 20, global step 504: 'val_loss' reached 0.79147 (best 0.79147), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=20-step=504.ckpt' as top 1
# Epoch 21: 100%|█| 24/24 [00:12<00:00,  1.94it/s, v_num=f3hs, val_loss=0.791, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.60it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.43it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.27it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.31it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.55it/s]Saved best model 0.7831796407699585 -> 0.779074992452349
#
# Epoch 21: 100%|█| 24/24 [00:13<00:00,  1.79it/s, v_num=f3hs, val_loss=0.786, traEpoch 21, global step 528: 'val_loss' reached 0.78643 (best 0.78643), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=21-step=528.ckpt' as top 1
# Epoch 22: 100%|█| 24/24 [00:12<00:00,  1.99it/s, v_num=f3hs, val_loss=0.786, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 15.11it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 16.05it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 16.68it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 17.13it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 19.52it/s]
# Epoch 22: 100%|█| 24/24 [00:13<00:00,  1.84it/s, v_num=f3hs, val_loss=0.789, traEpoch 22, global step 552: 'val_loss' was not in top 1
# Epoch 23: 100%|█| 24/24 [00:11<00:00,  2.11it/s, v_num=f3hs, val_loss=0.789, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.59it/s]Saved best model 0.779074992452349 -> 0.7721594061170306
#
# Epoch 23: 100%|█| 24/24 [00:12<00:00,  1.96it/s, v_num=f3hs, val_loss=0.784, traEpoch 23, global step 576: 'val_loss' reached 0.78404 (best 0.78404), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=23-step=576.ckpt' as top 1
# Epoch 24: 100%|█| 24/24 [00:12<00:00,  1.91it/s, v_num=f3hs, val_loss=0.784, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.45it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.40it/s]Saved best model 0.7721594061170306 -> 0.7721105473382133
#
# Epoch 24: 100%|█| 24/24 [00:13<00:00,  1.79it/s, v_num=f3hs, val_loss=0.781, traEpoch 24, global step 600: 'val_loss' reached 0.78133 (best 0.78133), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=24-step=600.ckpt' as top 1
# Epoch 25: 100%|█| 24/24 [00:11<00:00,  2.04it/s, v_num=f3hs, val_loss=0.781, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.40it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.35it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.51it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.16it/s]
# Epoch 25: 100%|█| 24/24 [00:12<00:00,  1.90it/s, v_num=f3hs, val_loss=0.793, traEpoch 25, global step 624: 'val_loss' was not in top 1
# Epoch 26: 100%|█| 24/24 [00:12<00:00,  1.88it/s, v_num=f3hs, val_loss=0.793, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.07it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.96it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.57it/s]Saved best model 0.7721105473382133 -> 0.7661542040961129
#
# Epoch 26: 100%|█| 24/24 [00:13<00:00,  1.76it/s, v_num=f3hs, val_loss=0.776, traEpoch 26, global step 648: 'val_loss' reached 0.77596 (best 0.77596), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=26-step=648.ckpt' as top 1
# Epoch 27: 100%|█| 24/24 [00:12<00:00,  1.98it/s, v_num=f3hs, val_loss=0.776, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.14it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.12it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.18it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.14it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.16it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.74it/s]Saved best model 0.7661542040961129 -> 0.7593485457556588
#
# Epoch 27: 100%|█| 24/24 [00:13<00:00,  1.84it/s, v_num=f3hs, val_loss=0.771, traEpoch 27, global step 672: 'val_loss' reached 0.77065 (best 0.77065), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=27-step=672.ckpt' as top 1
# Epoch 28: 100%|█| 24/24 [00:12<00:00,  1.95it/s, v_num=f3hs, val_loss=0.771, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.47it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.39it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.41it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.90it/s]
# Epoch 28: 100%|█| 24/24 [00:13<00:00,  1.82it/s, v_num=f3hs, val_loss=0.782, traEpoch 28, global step 696: 'val_loss' was not in top 1
# Epoch 29: 100%|█| 24/24 [00:12<00:00,  1.90it/s, v_num=f3hs, val_loss=0.782, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.62it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.59it/s]Saved best model 0.7593485457556588 -> 0.7557328343391418
#
# Epoch 29: 100%|█| 24/24 [00:13<00:00,  1.77it/s, v_num=f3hs, val_loss=0.768, traEpoch 29, global step 720: 'val_loss' reached 0.76782 (best 0.76782), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=29-step=720.ckpt' as top 1
# Epoch 30: 100%|█| 24/24 [00:11<00:00,  2.02it/s, v_num=f3hs, val_loss=0.768, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.07it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.92it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.33it/s]Saved best model 0.7557328343391418 -> 0.7503516674041748
#
# Epoch 30: 100%|█| 24/24 [00:12<00:00,  1.88it/s, v_num=f3hs, val_loss=0.766, traEpoch 30, global step 744: 'val_loss' reached 0.76561 (best 0.76561), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=30-step=744.ckpt' as top 1
# Epoch 31: 100%|█| 24/24 [00:12<00:00,  1.95it/s, v_num=f3hs, val_loss=0.766, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.00it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.24it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.36it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.43it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.45it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.13it/s]
# Epoch 31: 100%|█| 24/24 [00:13<00:00,  1.81it/s, v_num=f3hs, val_loss=0.775, traEpoch 31, global step 768: 'val_loss' was not in top 1
# Epoch 32: 100%|█| 24/24 [00:11<00:00,  2.12it/s, v_num=f3hs, val_loss=0.775, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.63it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.55it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.56it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.56it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.49it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.46it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.90it/s]
# Epoch 32: 100%|█| 24/24 [00:12<00:00,  1.96it/s, v_num=f3hs, val_loss=0.764, traEpoch 32, global step 792: 'val_loss' reached 0.76405 (best 0.76405), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=32-step=792.ckpt' as top 1
# Epoch 33: 100%|█| 24/24 [00:12<00:00,  1.98it/s, v_num=f3hs, val_loss=0.764, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.09it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.15it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.81it/s]
# Epoch 33: 100%|█| 24/24 [00:12<00:00,  1.85it/s, v_num=f3hs, val_loss=0.766, traEpoch 33, global step 816: 'val_loss' was not in top 1
# Epoch 34: 100%|█| 24/24 [00:12<00:00,  1.93it/s, v_num=f3hs, val_loss=0.766, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.03it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.10it/s]Saved best model 0.7503516674041748 -> 0.7479771716254098
#
# Epoch 34: 100%|█| 24/24 [00:13<00:00,  1.78it/s, v_num=f3hs, val_loss=0.763, traEpoch 34, global step 840: 'val_loss' reached 0.76257 (best 0.76257), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=34-step=840.ckpt' as top 1
# Epoch 35: 100%|█| 24/24 [00:11<00:00,  2.03it/s, v_num=f3hs, val_loss=0.763, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.80it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.85it/s]Saved best model 0.7479771716254098 -> 0.7453904833112445
#
# Epoch 35: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=f3hs, val_loss=0.759, traEpoch 35, global step 864: 'val_loss' reached 0.75863 (best 0.75863), saving model to 'output/wandb_logs/CZII-G/7mo0f3hs/checkpoints/epoch=35-step=864.ckpt' as top 1
# Epoch 36: 100%|█| 24/24 [00:12<00:00,  2.00it/s, v_num=f3hs, val_loss=0.759, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.17it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.05it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.06it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.02it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.98it/s]
# Epoch 36: 100%|█| 24/24 [00:12<00:00,  1.86it/s, v_num=f3hs, val_loss=0.760, traEpoch 36, global step 888: 'val_loss' was not in top 1
# Epoch 37: 100%|█| 24/24 [00:11<00:00,  2.03it/s, v_num=f3hs, val_loss=0.760, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.36it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.39it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.40it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.65it/s]
# Epoch 37: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=f3hs, val_loss=0.766, traEpoch 37, global step 912: 'val_loss' was not in top 1
# Epoch 38: 100%|█| 24/24 [00:11<00:00,  2.01it/s, v_num=f3hs, val_loss=0.766, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.55it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.52it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.49it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.55it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.06it/s]
# Epoch 38: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=f3hs, val_loss=0.763, traEpoch 38, global step 936: 'val_loss' was not in top 1
# Epoch 39: 100%|█| 24/24 [00:12<00:00,  1.93it/s, v_num=f3hs, val_loss=0.763, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.53it/s]
# ...
# Epoch 47: 100%|█| 24/24 [00:13<00:00,  1.84it/s, v_num=5fvj, val_loss=0.736, traEpoch 47, global step 1152: 'val_loss' was not in top 1
# Epoch 48: 100%|█| 24/24 [00:12<00:00,  1.98it/s, v_num=5fvj, val_loss=0.736, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.23it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.21it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.11it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.09it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.10it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.08it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.69it/s]
# Epoch 48: 100%|█| 24/24 [00:13<00:00,  1.83it/s, v_num=5fvj, val_loss=0.742, traEpoch 48, global step 1176: 'val_loss' was not in top 1
# Epoch 49: 100%|█| 24/24 [00:12<00:00,  1.93it/s, v_num=5fvj, val_loss=0.742, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.64it/s]
# Epoch 49: 100%|█| 24/24 [00:13<00:00,  1.80it/s, v_num=5fvj, val_loss=0.734, traEpoch 49, global step 1200: 'val_loss' was not in top 1
# Epoch 50: 100%|█| 24/24 [00:11<00:00,  2.07it/s, v_num=5fvj, val_loss=0.734, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.19it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.09it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.06it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.04it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.99it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.72it/s]
# Epoch 50: 100%|█| 24/24 [00:12<00:00,  1.92it/s, v_num=5fvj, val_loss=0.736, traEpoch 50, global step 1224: 'val_loss' was not in top 1
# Epoch 51: 100%|█| 24/24 [00:12<00:00,  1.95it/s, v_num=5fvj, val_loss=0.736, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.12it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.09it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.98it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.59it/s]
# Epoch 51: 100%|█| 24/24 [00:13<00:00,  1.81it/s, v_num=5fvj, val_loss=0.743, traEpoch 51, global step 1248: 'val_loss' was not in top 1
# Epoch 52: 100%|█| 24/24 [00:12<00:00,  1.94it/s, v_num=5fvj, val_loss=0.743, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.16it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.99it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.03it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.67it/s]
# Epoch 52: 100%|█| 24/24 [00:13<00:00,  1.80it/s, v_num=5fvj, val_loss=0.741, traEpoch 52, global step 1272: 'val_loss' was not in top 1
# Epoch 53: 100%|█| 24/24 [00:12<00:00,  1.95it/s, v_num=5fvj, val_loss=0.741, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.26it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.18it/s]
# Epoch 53: 100%|█| 24/24 [00:13<00:00,  1.81it/s, v_num=5fvj, val_loss=0.734, traEpoch 53, global step 1296: 'val_loss' was not in top 1
# Epoch 54: 100%|█| 24/24 [00:12<00:00,  1.94it/s, v_num=5fvj, val_loss=0.734, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.22it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.00it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.97it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.97it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.99it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.69it/s]Saved best model 0.749128486428942 -> 0.7487588950565883
#
# Epoch 54: 100%|█| 24/24 [00:13<00:00,  1.80it/s, v_num=5fvj, val_loss=0.733, traEpoch 54, global step 1320: 'val_loss' reached 0.73298 (best 0.73298), saving model to 'output/wandb_logs/CZII-G/1umm5fvj/checkpoints/epoch=54-step=1320.ckpt' as top 1
# Epoch 55: 100%|█| 24/24 [00:11<00:00,  2.01it/s, v_num=5fvj, val_loss=0.733, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.11it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.97it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.97it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.41it/s]Saved best model 0.7487588950565883 -> 0.7440893479755947
#
# Epoch 55: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=5fvj, val_loss=0.728, traEpoch 55, global step 1344: 'val_loss' reached 0.72764 (best 0.72764), saving model to 'output/wandb_logs/CZII-G/1umm5fvj/checkpoints/epoch=55-step=1344.ckpt' as top 1
# Epoch 56: 100%|█| 24/24 [00:12<00:00,  1.95it/s, v_num=5fvj, val_loss=0.728, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.35it/s]
# Epoch 56: 100%|█| 24/24 [00:13<00:00,  1.77it/s, v_num=5fvj, val_loss=0.730, traEpoch 56, global step 1368: 'val_loss' was not in top 1
# Epoch 57: 100%|█| 24/24 [00:12<00:00,  1.92it/s, v_num=5fvj, val_loss=0.730, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.14it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.75it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.24it/s]
# Epoch 57: 100%|█| 24/24 [00:13<00:00,  1.79it/s, v_num=5fvj, val_loss=0.729, traEpoch 57, global step 1392: 'val_loss' was not in top 1
# Epoch 58: 100%|█| 24/24 [00:11<00:00,  2.01it/s, v_num=5fvj, val_loss=0.729, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.97it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.97it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.02it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.59it/s]
# Epoch 58: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=5fvj, val_loss=0.731, traEpoch 58, global step 1416: 'val_loss' was not in top 1
# Epoch 59: 100%|█| 24/24 [00:11<00:00,  2.06it/s, v_num=5fvj, val_loss=0.731, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.33it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.24it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.22it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.13it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.14it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.08it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.75it/s]
# Epoch 59: 100%|█| 24/24 [00:12<00:00,  1.91it/s, v_num=5fvj, val_loss=0.730, traEpoch 59, global step 1440: 'val_loss' was not in top 1
# Epoch 60: 100%|█| 24/24 [00:11<00:00,  2.03it/s, v_num=5fvj, val_loss=0.730, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.96it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.80it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.35it/s]
# Epoch 60: 100%|█| 24/24 [00:12<00:00,  1.87it/s, v_num=5fvj, val_loss=0.730, traEpoch 60, global step 1464: 'val_loss' was not in top 1
# Epoch 61: 100%|█| 24/24 [00:12<00:00,  1.93it/s, v_num=5fvj, val_loss=0.730, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.09it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.08it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.98it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.55it/s]
# Epoch 61: 100%|█| 24/24 [00:13<00:00,  1.80it/s, v_num=5fvj, val_loss=0.739, traEpoch 61, global step 1488: 'val_loss' was not in top 1
# Epoch 62: 100%|█| 24/24 [00:12<00:00,  1.99it/s, v_num=5fvj, val_loss=0.739, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.52it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.47it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.46it/s]
# Epoch 62: 100%|█| 24/24 [00:13<00:00,  1.83it/s, v_num=5fvj, val_loss=0.729, traEpoch 62, global step 1512: 'val_loss' was not in top 1
# Epoch 63:  79%|▊| 19/24 [00:10<00:02,  1.77it/s, v_num=5fvj, val_loss=0.729, tra
