# %%
import torch
import gc
import wandb

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
PROJECT_ID = 'H'
MODE = 'fine-tuning'

BASE_DIR = f"/kaggle/project/{PROJECT_ID}/{MODE}"

# %%
# %cd {BASE_DIR}
# Out:
# /kaggle/project/H/fine-tuning

# %%
data_dir = '/kaggle/input/numpy-dataset'

exp_nos = ['004']
# select_folds = [1, 2, 3, 4]
# select_folds = [2, 3, 4]
# select_folds = [3, 4, 5, 6]
# select_folds = [2]
# select_folds = [1, 3, 4]
# select_folds = [4]
select_folds = [1]
# select_folds = [0, 1, 2, 3, 4, 5, 6]

model = 'Unet'
batch_size_train = 2
batch_size_valid = 16
num_workers = 0
epoch = 1000
lr = 0.001

num_samples = int(16)
spatial_size = int(96)
patch_size = int(96)

pre_training = False
weight_path = None
if MODE == 'fine-tuning':
    pre_training = True
    weight_path = '/kaggle/project/H/pre-training/output/train/001/001-2/single/best_model.pth'
    data_dir = '/kaggle/input/numpy-dataset'
    epoch = 1000
    # lr *= 0.1

# %%
for i, exp_no in enumerate(exp_nos):
    project = f'CZII-{PROJECT_ID}-{MODE}'
    output_dir = f'{BASE_DIR}/output'

    for valid_fold in select_folds:
        exp_name = f'{exp_no}-{valid_fold}'
        split = f'fold_{valid_fold}'

        # !python -m run.train\
            project=$project\
            pre_training=$pre_training\
            weight_path=$weight_path\
            exp_no=$exp_no\
            exp_name=$exp_name\
            dir.data_dir=$data_dir\
            dir.output_dir=$output_dir\
            split=$split\
            model=$model\
            batch_size_train=$batch_size_train\
            batch_size_valid=$batch_size_valid\
            num_samples=$num_samples\
            spatial_size=$spatial_size\
            patch_size=$patch_size\
            num_workers=$num_workers\
            epoch=$epoch\
            optimizer.lr=$lr

        wandb.finish()

        torch.cuda.empty_cache()
        gc.collect()
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.24 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 2024-12-28 04:11:11.707125: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-28 04:11:12.193269: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
