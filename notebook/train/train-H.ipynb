# %%
import torch
import gc
import wandb

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
PROJECT_ID = 'H'
MODE = 'fine-tuning'

BASE_DIR = f"/kaggle/project/{PROJECT_ID}/{MODE}"

# %%
# %cd {BASE_DIR}
# Out:
# /kaggle/project/H/fine-tuning

# %%
data_dir = '/kaggle/input/numpy-dataset'

exp_nos = ['007']
# select_folds = [1, 2, 3, 4]
select_folds = [2, 3, 4]
# select_folds = [3, 4, 5, 6]
# select_folds = [2]
# select_folds = [1, 3, 4]
# select_folds = [4]
# select_folds = [1]
# select_folds = [0, 1, 2, 3, 4, 5, 6]

model = 'Unet'
batch_size_train = 2
batch_size_valid = 16
num_workers = 8
epoch = 50 * 8
lr = 0.001

num_samples = int(16)
spatial_size = int(96)
patch_size = int(96)

pre_training = False
weight_path = None
if MODE == 'fine-tuning':
    pre_training = True
    weight_path = '/kaggle/project/H/pre-training/output/train/001/001-2/single/best_model.pth'
    data_dir = '/kaggle/input/numpy-dataset'
    epoch = 50 * 8
    # lr *= 0.1

# %%
for i, exp_no in enumerate(exp_nos):
    project = f'CZII-{PROJECT_ID}-{MODE}'
    output_dir = f'{BASE_DIR}/output'

    for valid_fold in select_folds:
        exp_name = f'{exp_no}-{valid_fold}'
        split = f'fold_{valid_fold}'

        # !python -m run.train\
            project=$project\
            pre_training=$pre_training\
            weight_path=$weight_path\
            exp_no=$exp_no\
            exp_name=$exp_name\
            dir.data_dir=$data_dir\
            dir.output_dir=$output_dir\
            split=$split\
            model=$model\
            batch_size_train=$batch_size_train\
            batch_size_valid=$batch_size_valid\
            num_samples=$num_samples\
            spatial_size=$spatial_size\
            patch_size=$patch_size\
            num_workers=$num_workers\
            epoch=$epoch\
            optimizer.lr=$lr

        wandb.finish()

        torch.cuda.empty_cache()
        gc.collect()
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.24 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 2025-01-07 19:57:31.086027: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-07 19:57:31.093003: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-07 19:57:31.102303: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-07 19:57:31.104706: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-07 19:57:31.110541: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-07 19:57:31.585496: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [2025-01-07 19:57:32,160][train.py][INFO] - Set Up DataModule
# Loading dataset: 100%|██████████████████████████| 12/12 [00:00<00:00, 15.70it/s]
# Loading dataset: 100%|█████████████████████████| 98/98 [00:00<00:00, 335.28it/s]
# /kaggle/project/H/fine-tuning/src/models/common.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(cfg.weight_path))
# load weight from "/kaggle/project/H/pre-training/output/train/001/001-2/single/best_model.pth"
# Loading dataset: 100%|██████████████████████████| 12/12 [00:00<00:00, 15.68it/s]
# Loading dataset: 100%|██████████████████████████| 12/12 [00:00<00:00, 15.58it/s]
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:571: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# [2025-01-07 19:57:37,365][pytorch_lightning.utilities.rank_zero][INFO] - Using 16bit Automatic Mixed Precision (AMP)
# [2025-01-07 19:57:37,365][pytorch_lightning.utilities.rank_zero][INFO] - Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# [2025-01-07 19:57:37,375][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True (cuda), used: True
# [2025-01-07 19:57:37,375][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2025-01-07 19:57:37,375][pytorch_lightning.utilities.rank_zero][INFO] - HPU available: False, using: 0 HPUs
# [2025-01-07 19:57:37,376][pytorch_lightning.utilities.rank_zero][INFO] - You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: naoya-takashima. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path output/wandb_logs/wandb/ wasn't writable, using system temp directory.
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /tmp/wandb/run-20250107_195738-cotgicze
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 007-2
# wandb: ⭐️ View project at https://wandb.ai/naoya-takashima/CZII-H-fine-tuning
# wandb: 🚀 View run at https://wandb.ai/naoya-takashima/CZII-H-fine-tuning/runs/cotgicze
# [2025-01-07 19:57:38,826][pytorch_lightning.accelerators.cuda][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name               ┃ Type             ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ model              │ Unet             │  1.1 M │ train │
# │ 1 │ model.model        │ UNet             │  1.1 M │ train │
# │ 2 │ model.loss_fn_tv   │ TverskyLoss      │      0 │ train │
# │ 3 │ model.loss_fn_dice │ DiceLoss         │      0 │ train │
# │ 4 │ model.loss_fn_ce   │ CrossEntropyLoss │      0 │ train │
# └───┴────────────────────┴──────────────────┴────────┴───────┘
# Trainable params: 1.1 M
# Non-trainable params: 0
# Total params: 1.1 M
# Total estimated model params size (MB): 4
# Modules in train mode: 91
# Modules in eval mode: 0
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 0: 100%|████████████████████████| 6/6 [00:06<00:00,  0.91it/s, v_num=icze]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.07it/s]Saved best model inf -> 0.8265172328267779
#
# Epoch 0: 100%|█| 6/6 [00:07<00:00,  0.82it/s, v_num=icze, val_loss=0.830, train_[2025-01-07 19:57:46,332][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 0, global step 6: 'val_loss' reached 0.82994 (best 0.82994), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=0-step=6.ckpt' as top 1
# Epoch 1: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=icze, val_loss=0.830, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.50it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.44it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.35it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.01it/s]Saved best model 0.8265172328267779 -> 0.8224037204469953
#
# Epoch 1: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.825, train_[2025-01-07 19:57:52,952][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 1, global step 12: 'val_loss' reached 0.82489 (best 0.82489), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=1-step=12.ckpt' as top 1
# Epoch 2: 100%|█| 6/6 [00:06<00:00,  1.00it/s, v_num=icze, val_loss=0.825, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.73it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.80it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.45it/s]Saved best model 0.8224037204469953 -> 0.8169655203819275
#
# Epoch 2: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=icze, val_loss=0.819, train_[2025-01-07 19:57:59,541][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 2, global step 18: 'val_loss' reached 0.81926 (best 0.81926), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=2-step=18.ckpt' as top 1
# Epoch 3: 100%|█| 6/6 [00:06<00:00,  0.93it/s, v_num=icze, val_loss=0.819, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.62it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.35it/s]Saved best model 0.8169655203819275 -> 0.8065860526902335
#
# Epoch 3: 100%|█| 6/6 [00:07<00:00,  0.85it/s, v_num=icze, val_loss=0.810, train_[2025-01-07 19:58:06,616][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 3, global step 24: 'val_loss' reached 0.81027 (best 0.81027), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=3-step=24.ckpt' as top 1
# Epoch 4: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=icze, val_loss=0.810, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.04it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.51it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.28it/s]
# Epoch 4: 100%|█| 6/6 [00:07<00:00,  0.81it/s, v_num=icze, val_loss=0.811, train_[2025-01-07 19:58:14,050][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 4, global step 30: 'val_loss' was not in top 1
# Epoch 5: 100%|█| 6/6 [00:06<00:00,  0.86it/s, v_num=icze, val_loss=0.811, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.41it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.42it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.32it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.31it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.39it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.05it/s]
# Epoch 5: 100%|█| 6/6 [00:07<00:00,  0.80it/s, v_num=icze, val_loss=0.824, train_[2025-01-07 19:58:21,587][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 5, global step 36: 'val_loss' was not in top 1
# Epoch 6: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=icze, val_loss=0.824, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.33it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.60it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.32it/s]Saved best model 0.8065860526902335 -> 0.7921569091933114
#
# Epoch 6: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.798, train_[2025-01-07 19:58:28,183][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 6, global step 42: 'val_loss' reached 0.79792 (best 0.79792), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=6-step=42.ckpt' as top 1
# Epoch 7: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=icze, val_loss=0.798, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.00it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.39it/s]Saved best model 0.7921569091933114 -> 0.7907910006386893
#
# Epoch 7: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.797, train_[2025-01-07 19:58:34,987][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 7, global step 48: 'val_loss' reached 0.79720 (best 0.79720), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=7-step=48.ckpt' as top 1
# Epoch 8: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=icze, val_loss=0.797, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.55it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.35it/s]Saved best model 0.7907910006386893 -> 0.7824464440345764
#
# Epoch 8: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.790, train_[2025-01-07 19:58:41,760][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 8, global step 54: 'val_loss' reached 0.79045 (best 0.79045), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=8-step=54.ckpt' as top 1
# Epoch 9: 100%|█| 6/6 [00:05<00:00,  1.00it/s, v_num=icze, val_loss=0.790, train_
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.09it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.33it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.42it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.48it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.15it/s]
# Epoch 9: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=icze, val_loss=0.800, train_[2025-01-07 19:58:48,350][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 9, global step 60: 'val_loss' was not in top 1
# Epoch 10: 100%|█| 6/6 [00:06<00:00,  0.87it/s, v_num=icze, val_loss=0.800, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.26it/s]
# Epoch 10: 100%|█| 6/6 [00:07<00:00,  0.81it/s, v_num=icze, val_loss=0.793, train[2025-01-07 19:58:55,747][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 10, global step 66: 'val_loss' was not in top 1
# Epoch 11: 100%|█| 6/6 [00:05<00:00,  1.02it/s, v_num=icze, val_loss=0.793, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.37it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.55it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.41it/s]Saved best model 0.7824464440345764 -> 0.777374301637922
#
# Epoch 11: 100%|█| 6/6 [00:06<00:00,  0.94it/s, v_num=icze, val_loss=0.785, train[2025-01-07 19:59:02,143][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 11, global step 72: 'val_loss' reached 0.78467 (best 0.78467), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=11-step=72.ckpt' as top 1
# Epoch 12: 100%|█| 6/6 [00:06<00:00,  1.00it/s, v_num=icze, val_loss=0.785, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.49it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.24it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.30it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.42it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.47it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.42it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.05it/s]Saved best model 0.777374301637922 -> 0.7710175599370684
#
# Epoch 12: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.781, train[2025-01-07 19:59:08,752][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 12, global step 78: 'val_loss' reached 0.78098 (best 0.78098), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=12-step=78.ckpt' as top 1
# Epoch 13: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=icze, val_loss=0.781, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.29it/s]
# Epoch 13: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.784, train[2025-01-07 19:59:15,530][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 13, global step 84: 'val_loss' was not in top 1
# Epoch 14: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=icze, val_loss=0.784, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.73it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.43it/s]Saved best model 0.7710175599370684 -> 0.7660982949393136
#
# Epoch 14: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.777, train[2025-01-07 19:59:22,135][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 14, global step 90: 'val_loss' reached 0.77687 (best 0.77687), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=14-step=90.ckpt' as top 1
# Epoch 15: 100%|█| 6/6 [00:06<00:00,  0.90it/s, v_num=icze, val_loss=0.777, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.40it/s]
# Epoch 15: 100%|█| 6/6 [00:07<00:00,  0.83it/s, v_num=icze, val_loss=0.775, train[2025-01-07 19:59:29,383][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 15, global step 96: 'val_loss' reached 0.77529 (best 0.77529), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=15-step=96.ckpt' as top 1
# Epoch 16: 100%|█| 6/6 [00:05<00:00,  1.01it/s, v_num=icze, val_loss=0.775, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.80it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.73it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.22it/s]
# Epoch 16: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=icze, val_loss=0.782, train[2025-01-07 19:59:35,950][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 16, global step 102: 'val_loss' was not in top 1
# Epoch 17: 100%|█| 6/6 [00:05<00:00,  1.03it/s, v_num=icze, val_loss=0.782, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.51it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.33it/s]Saved best model 0.7660982949393136 -> 0.7613005978720528
#
# Epoch 17: 100%|█| 6/6 [00:06<00:00,  0.94it/s, v_num=icze, val_loss=0.771, train[2025-01-07 19:59:42,346][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 17, global step 108: 'val_loss' reached 0.77089 (best 0.77089), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=17-step=108.ckpt' as top 1
# Epoch 18: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.771, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.75it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.73it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.37it/s]Saved best model 0.7613005978720528 -> 0.7603788205555507
#
# Epoch 18: 100%|█| 6/6 [00:07<00:00,  0.84it/s, v_num=icze, val_loss=0.770, train[2025-01-07 19:59:49,557][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 18, global step 114: 'val_loss' reached 0.76976 (best 0.76976), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=18-step=114.ckpt' as top 1
# Epoch 19: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=icze, val_loss=0.770, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.13it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.14it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.13it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.14it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.16it/s]
# Epoch 19: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.775, train[2025-01-07 19:59:56,367][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 19, global step 120: 'val_loss' was not in top 1
# Epoch 20: 100%|█| 6/6 [00:06<00:00,  0.90it/s, v_num=icze, val_loss=0.775, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.00it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.73it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.45it/s]Saved best model 0.7603788205555507 -> 0.7600483468600682
#
# Epoch 20: 100%|█| 6/6 [00:07<00:00,  0.83it/s, v_num=icze, val_loss=0.772, train[2025-01-07 20:00:03,571][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 20, global step 126: 'val_loss' was not in top 1
# Epoch 21: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=icze, val_loss=0.772, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.77it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.60it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.35it/s]
# Epoch 21: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=icze, val_loss=0.778, train[2025-01-07 20:00:10,379][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 21, global step 132: 'val_loss' was not in top 1
# Epoch 22: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=icze, val_loss=0.778, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.30it/s]
# Epoch 22: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.770, train[2025-01-07 20:00:17,134][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 22, global step 138: 'val_loss' was not in top 1
# Epoch 23: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=icze, val_loss=0.770, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.29it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.51it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.56it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.61it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.36it/s]Saved best model 0.7600483468600682 -> 0.7549100858824593
#
# Epoch 23: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=icze, val_loss=0.766, train[2025-01-07 20:00:23,970][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 23, global step 144: 'val_loss' reached 0.76578 (best 0.76578), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=23-step=144.ckpt' as top 1
# Epoch 24: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=icze, val_loss=0.766, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.62it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.30it/s]Saved best model 0.7549100858824593 -> 0.7511779921395438
#
# Epoch 24: 100%|█| 6/6 [00:07<00:00,  0.82it/s, v_num=icze, val_loss=0.762, train[2025-01-07 20:00:31,352][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 24, global step 150: 'val_loss' reached 0.76221 (best 0.76221), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=24-step=150.ckpt' as top 1
# Epoch 25: 100%|█| 6/6 [00:06<00:00,  0.98it/s, v_num=icze, val_loss=0.762, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.73it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.62it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.32it/s]Saved best model 0.7511779921395438 -> 0.7471179025513786
#
# Epoch 25: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.756, train[2025-01-07 20:00:38,133][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 25, global step 156: 'val_loss' reached 0.75613 (best 0.75613), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=25-step=156.ckpt' as top 1
# Epoch 26: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=icze, val_loss=0.756, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.42it/s]Saved best model 0.7471179025513786 -> 0.7414641210011074
#
# Epoch 26: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=icze, val_loss=0.753, train[2025-01-07 20:00:44,967][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 26, global step 162: 'val_loss' reached 0.75321 (best 0.75321), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=26-step=162.ckpt' as top 1
# Epoch 27: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.753, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.58it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.60it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.62it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.31it/s]
# Epoch 27: 100%|█| 6/6 [00:07<00:00,  0.84it/s, v_num=icze, val_loss=0.756, train[2025-01-07 20:00:52,182][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 27, global step 168: 'val_loss' was not in top 1
# Epoch 28: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.756, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.81it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.42it/s]Saved best model 0.7414641210011074 -> 0.7399100320679801
#
# Epoch 28: 100%|█| 6/6 [00:07<00:00,  0.83it/s, v_num=icze, val_loss=0.753, train[2025-01-07 20:00:59,387][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 28, global step 174: 'val_loss' was not in top 1
# Epoch 29: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=icze, val_loss=0.753, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.78it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.50it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.17it/s]
# Epoch 29: 100%|█| 6/6 [00:07<00:00,  0.84it/s, v_num=icze, val_loss=0.752, train[2025-01-07 20:01:06,550][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 29, global step 180: 'val_loss' reached 0.75166 (best 0.75166), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=29-step=180.ckpt' as top 1
# Epoch 30: 100%|█| 6/6 [00:05<00:00,  1.00it/s, v_num=icze, val_loss=0.752, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.64it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.65it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.68it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.67it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.34it/s]
# Epoch 30: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=icze, val_loss=0.773, train[2025-01-07 20:01:13,143][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 30, global step 186: 'val_loss' was not in top 1
# Epoch 31: 100%|█| 6/6 [00:05<00:00,  1.06it/s, v_num=icze, val_loss=0.773, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.92it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.62it/s]Saved best model 0.7399100320679801 -> 0.737804821559361
#
# Epoch 31: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=icze, val_loss=0.751, train[2025-01-07 20:01:19,361][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 31, global step 192: 'val_loss' reached 0.75118 (best 0.75118), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=31-step=192.ckpt' as top 1
# Epoch 32: 100%|█| 6/6 [00:05<00:00,  1.00it/s, v_num=icze, val_loss=0.751, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.59it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.52it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.18it/s]Saved best model 0.737804821559361 -> 0.7371714881488255
#
# Epoch 32: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=icze, val_loss=0.747, train[2025-01-07 20:01:25,933][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 32, global step 198: 'val_loss' reached 0.74749 (best 0.74749), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=32-step=198.ckpt' as top 1
# Epoch 33: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=icze, val_loss=0.747, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.53it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.71it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.72it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.44it/s]
# Epoch 33: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=icze, val_loss=0.747, train[2025-01-07 20:01:32,709][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 33, global step 204: 'val_loss' reached 0.74738 (best 0.74738), saving model to 'output/wandb_logs/CZII-H-fine-tuning/cotgicze/checkpoints/epoch=33-step=204.ckpt' as top 1
# Epoch 34: 100%|█| 6/6 [00:06<00:00,  0.94it/s, v_num=icze, val_loss=0.747, train
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.82it/s]
# ...
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.43it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.10it/s]
# Epoch 385: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:02,777][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 385, global step 2316: 'val_loss' was not in top 1
# Epoch 386: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.60it/s]
# Epoch 386: 100%|█| 6/6 [00:07<00:00,  0.81it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:10,148][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 386, global step 2322: 'val_loss' was not in top 1
# Epoch 387: 100%|█| 6/6 [00:05<00:00,  1.06it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.69it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.42it/s]
# Epoch 387: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:16,335][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 387, global step 2328: 'val_loss' was not in top 1
# Epoch 388: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.11it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.02it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.00it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.96it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.64it/s]
# Epoch 388: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:22,943][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 388, global step 2334: 'val_loss' was not in top 1
# Epoch 389: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.66it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.63it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.46it/s]
# Epoch 389: 100%|█| 6/6 [00:06<00:00,  0.91it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:29,571][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 389, global step 2340: 'val_loss' was not in top 1
# Epoch 390: 100%|█| 6/6 [00:06<00:00,  0.97it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.31it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.20it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.93it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.64it/s]
# Epoch 390: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:36,300][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 390, global step 2346: 'val_loss' was not in top 1
# Epoch 391: 100%|█| 6/6 [00:06<00:00,  0.93it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.52it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.29it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.22it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.21it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.19it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.89it/s]
# Epoch 391: 100%|█| 6/6 [00:07<00:00,  0.85it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:43,368][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 391, global step 2352: 'val_loss' was not in top 1
# Epoch 392: 100%|█| 6/6 [00:06<00:00,  0.94it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.89it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.68it/s]
# Epoch 392: 100%|█| 6/6 [00:06<00:00,  0.86it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:50,313][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 392, global step 2358: 'val_loss' was not in top 1
# Epoch 393: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.67it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.85it/s]
# Epoch 393: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:14:57,161][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 393, global step 2364: 'val_loss' was not in top 1
# Epoch 394: 100%|█| 6/6 [00:05<00:00,  1.00it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 17.96it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 18.48it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 18.77it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 18.97it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.13it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 21.69it/s]
# Epoch 394: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:15:03,703][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 394, global step 2370: 'val_loss' was not in top 1
# Epoch 395: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.80it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.85it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.88it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.87it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.57it/s]
# Epoch 395: 100%|█| 6/6 [00:06<00:00,  0.90it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:15:10,344][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 395, global step 2376: 'val_loss' was not in top 1
# Epoch 396: 100%|█| 6/6 [00:06<00:00,  0.99it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.16it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.22it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.50it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.54it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.57it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.07it/s]
# Epoch 396: 100%|█| 6/6 [00:06<00:00,  0.90it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:15:17,020][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 396, global step 2382: 'val_loss' was not in top 1
# Epoch 397: 100%|█| 6/6 [00:06<00:00,  0.92it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.02it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.98it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.95it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.91it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.59it/s]
# Epoch 397: 100%|█| 6/6 [00:07<00:00,  0.85it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:15:24,102][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 397, global step 2388: 'val_loss' was not in top 1
# Epoch 398: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.06it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.81it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.83it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.86it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.53it/s]
# Epoch 398: 100%|█| 6/6 [00:06<00:00,  0.88it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:15:30,909][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 398, global step 2394: 'val_loss' was not in top 1
# Epoch 399: 100%|█| 6/6 [00:06<00:00,  0.96it/s, v_num=cjnd, val_loss=0.703, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.81it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.79it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.84it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.90it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.92it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.94it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.61it/s]
# Epoch 399: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=cjnd, val_loss=0.703, trai[2025-01-07 22:15:37,681][pytorch_lightning.utilities.rank_zero][INFO] - Epoch 399, global step 2400: 'val_loss' was not in top 1
# [2025-01-07 22:15:37,682][pytorch_lightning.utilities.rank_zero][INFO] - `Trainer.fit` stopped: `max_steps=2400` reached.
# Epoch 399: 100%|█| 6/6 [00:06<00:00,  0.89it/s, v_num=cjnd, val_loss=0.703, trai
# wandb: 🚀 View run 007-4 at: https://wandb.ai/naoya-takashima/CZII-H-fine-tuning/runs/zxblcjnd
# wandb: Find logs at: ../../../../../../../../../tmp/wandb/run-20250107_212915-zxblcjnd/logs
