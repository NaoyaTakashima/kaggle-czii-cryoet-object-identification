# %%
import torch
import gc
import wandb

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
PROJECT_ID = 'I'

BASE_DIR = f"/home/naoya/kaggle/czii/project/{PROJECT_ID}"

# %%
# %cd {BASE_DIR}
# Out:
# /home/naoya/kaggle/czii/project/I

# %%
data_dir = '/home/naoya/kaggle/czii/input/numpy-dataset'

exp_nos = ['006']
# select_folds = [1, 2, 3, 4]
# select_folds = [2, 3, 4]
# select_folds = [3, 4, 5, 6]
select_folds = [1]
# select_folds = [2]
# select_folds = [1, 3, 4]

model = 'Unet'
num_res_units = 1

batch_size_train = 2
batch_size_valid = 16
num_workers = 8
epoch = 50 * 4
lr = 0.001

num_samples = int(16)
spatial_size = int(96)
patch_size = int(96)

# alpha = 0.7
# beta = 0.3

# %%
for i, exp_no in enumerate(exp_nos):
    project = f'CZII-{PROJECT_ID}'
    output_dir = f'{BASE_DIR}/output'

    for valid_fold in select_folds:
        exp_name = f'{exp_no}-{valid_fold}'
        split = f'fold_{valid_fold}'

        # !./run_with_retries.sh "python -m run.train\
            project=$project\
            exp_no=$exp_no\
            exp_name=$exp_name\
            dir.data_dir=$data_dir\
            dir.output_dir=$output_dir\
            split=$split\
            model=$model\
            model.num_res_units=$num_res_units\
            batch_size_train=$batch_size_train\
            batch_size_valid=$batch_size_valid\
            num_samples=$num_samples\
            spatial_size=$spatial_size\
            patch_size=$patch_size\
            num_workers=$num_workers\
            epoch=$epoch\
            optimizer.lr=$lr"

        wandb.finish()

        torch.cuda.empty_cache()
        gc.collect()
# Out:
# /home/naoya/kaggle/czii/.venv/lib/python3.12/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.22 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# [2024-12-17 03:09:37,344][train.py][INFO] - Set Up DataModule
# Loading dataset: 100%|██████████████████████████| 24/24 [00:01<00:00, 15.56it/s]
# Loading dataset: 100%|█████████████████████████| 98/98 [00:00<00:00, 325.94it/s]
# Loading dataset: 100%|██████████████████████████| 24/24 [00:01<00:00, 14.32it/s]
# Loading dataset: 100%|██████████████████████████| 24/24 [00:01<00:00, 15.54it/s]
# /home/naoya/kaggle/czii/.venv/lib/python3.12/site-packages/lightning_fabric/connector.py:571: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: naoya-takashima. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path output/wandb_logs/wandb/ wasn't writable, using system temp directory.
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /tmp/wandb/run-20241217_030949-p61ctrp0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 006-1
# wandb: ⭐️ View project at https://wandb.ai/naoya-takashima/CZII-I
# wandb: 🚀 View run at https://wandb.ai/naoya-takashima/CZII-I/runs/p61ctrp0
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name               ┃ Type             ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ model              │ Unet             │  1.1 M │ train │
# │ 1 │ model.model        │ UNet             │  1.1 M │ train │
# │ 2 │ model.loss_fn_tv   │ TverskyLoss      │      0 │ train │
# │ 3 │ model.loss_fn_dice │ DiceLoss         │      0 │ train │
# │ 4 │ model.loss_fn_ce   │ CrossEntropyLoss │      0 │ train │
# └───┴────────────────────┴──────────────────┴────────┴───────┘
# Trainable params: 1.1 M
# Non-trainable params: 0
# Total params: 1.1 M
# Total estimated model params size (MB): 4
# Modules in train mode: 91
# Modules in eval mode: 0
# Epoch 0: 100%|██████████████████████| 12/12 [00:05<00:00,  2.27it/s, v_num=trp0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.51it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.47it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.32it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.45it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.55it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.54it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.11it/s]Saved best model inf -> 0.6250658971922738
#
# Epoch 0: 100%|█| 12/12 [00:05<00:00,  2.02it/s, v_num=trp0, val_loss=0.625, traiEpoch 0, global step 12: 'val_loss' reached 0.62452 (best 0.62452), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=0-step=12.ckpt' as top 1
# Epoch 1: 100%|█| 12/12 [00:04<00:00,  2.69it/s, v_num=trp0, val_loss=0.625, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.62it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.52it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.56it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.46it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.51it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.51it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.29it/s]Saved best model 0.6250658971922738 -> 0.5944543821471078
#
# Epoch 1: 100%|█| 12/12 [00:04<00:00,  2.42it/s, v_num=trp0, val_loss=0.593, traiEpoch 1, global step 24: 'val_loss' reached 0.59335 (best 0.59335), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=1-step=24.ckpt' as top 1
# Epoch 2: 100%|█| 12/12 [00:04<00:00,  2.60it/s, v_num=trp0, val_loss=0.593, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.27it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.48it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.45it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.33it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.34it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.29it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.16it/s]Saved best model 0.5944543821471078 -> 0.5733433791569301
#
# Epoch 2: 100%|█| 12/12 [00:05<00:00,  2.33it/s, v_num=trp0, val_loss=0.572, traiEpoch 2, global step 36: 'val_loss' reached 0.57160 (best 0.57160), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=2-step=36.ckpt' as top 1
# Epoch 3: 100%|█| 12/12 [00:04<00:00,  2.57it/s, v_num=trp0, val_loss=0.572, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.16it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.32it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.43it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.39it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.44it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.21it/s]Saved best model 0.5733433791569301 -> 0.5587410245622907
#
# Epoch 3: 100%|█| 12/12 [00:05<00:00,  2.32it/s, v_num=trp0, val_loss=0.556, traiEpoch 3, global step 48: 'val_loss' reached 0.55637 (best 0.55637), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=3-step=48.ckpt' as top 1
# Epoch 4: 100%|█| 12/12 [00:04<00:00,  2.51it/s, v_num=trp0, val_loss=0.556, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.05it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.93it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.19it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.16it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.25it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.25it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.82it/s]Saved best model 0.5587410245622907 -> 0.5540230699947902
#
# Epoch 4: 100%|█| 12/12 [00:05<00:00,  2.27it/s, v_num=trp0, val_loss=0.551, traiEpoch 4, global step 60: 'val_loss' reached 0.55139 (best 0.55139), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=4-step=60.ckpt' as top 1
# Epoch 5: 100%|█| 12/12 [00:04<00:00,  2.62it/s, v_num=trp0, val_loss=0.551, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.82it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.16it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.34it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.14it/s]Saved best model 0.5540230699947902 -> 0.5516479696546283
#
# Epoch 5: 100%|█| 12/12 [00:05<00:00,  2.36it/s, v_num=trp0, val_loss=0.550, traiEpoch 5, global step 72: 'val_loss' reached 0.54976 (best 0.54976), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=5-step=72.ckpt' as top 1
# Epoch 6: 100%|█| 12/12 [00:04<00:00,  2.63it/s, v_num=trp0, val_loss=0.550, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.96it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.55it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.56it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.54it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.49it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.52it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.42it/s]
# Epoch 6: 100%|█| 12/12 [00:05<00:00,  2.36it/s, v_num=trp0, val_loss=0.552, traiEpoch 6, global step 84: 'val_loss' was not in top 1
# Epoch 7: 100%|█| 12/12 [00:04<00:00,  2.63it/s, v_num=trp0, val_loss=0.552, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.13it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.25it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.17it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.33it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.35it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.37it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.23it/s]Saved best model 0.5516479696546283 -> 0.5426793694496155
#
# Epoch 7: 100%|█| 12/12 [00:05<00:00,  2.35it/s, v_num=trp0, val_loss=0.541, traiEpoch 7, global step 96: 'val_loss' reached 0.54076 (best 0.54076), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=7-step=96.ckpt' as top 1
# Epoch 8: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.541, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.33it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.16it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.18it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.12it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.35it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.17it/s]Saved best model 0.5426793694496155 -> 0.5425674659865243
#
# Epoch 8: 100%|█| 12/12 [00:05<00:00,  2.28it/s, v_num=trp0, val_loss=0.542, traiEpoch 8, global step 108: 'val_loss' was not in top 1
# Epoch 9: 100%|█| 12/12 [00:04<00:00,  2.55it/s, v_num=trp0, val_loss=0.542, trai
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.50it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.13it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.36it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.50it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.30it/s]
# Epoch 9: 100%|█| 12/12 [00:05<00:00,  2.28it/s, v_num=trp0, val_loss=0.543, traiEpoch 9, global step 120: 'val_loss' was not in top 1
# Epoch 10: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.543, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.33it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.83it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.02it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.02it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.02it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.89it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.69it/s]Saved best model 0.5425674659865243 -> 0.5398453984941755
#
# Epoch 10: 100%|█| 12/12 [00:05<00:00,  2.28it/s, v_num=trp0, val_loss=0.540, traEpoch 10, global step 132: 'val_loss' reached 0.54011 (best 0.54011), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=10-step=132.ckpt' as top 1
# Epoch 11: 100%|█| 12/12 [00:04<00:00,  2.50it/s, v_num=trp0, val_loss=0.540, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.27it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.32it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.17it/s]Saved best model 0.5398453984941755 -> 0.5386368376868111
#
# Epoch 11: 100%|█| 12/12 [00:05<00:00,  2.24it/s, v_num=trp0, val_loss=0.539, traEpoch 11, global step 144: 'val_loss' reached 0.53862 (best 0.53862), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=11-step=144.ckpt' as top 1
# Epoch 12: 100%|█| 12/12 [00:04<00:00,  2.57it/s, v_num=trp0, val_loss=0.539, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.40it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.24it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.36it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.22it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.20it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.25it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.09it/s]Saved best model 0.5386368376868111 -> 0.5368532793862479
#
# Epoch 12: 100%|█| 12/12 [00:05<00:00,  2.30it/s, v_num=trp0, val_loss=0.541, traEpoch 12, global step 156: 'val_loss' was not in top 1
# Epoch 13: 100%|█| 12/12 [00:04<00:00,  2.60it/s, v_num=trp0, val_loss=0.541, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.52it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.36it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.34it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.37it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.38it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.23it/s]
# Epoch 13: 100%|█| 12/12 [00:05<00:00,  2.35it/s, v_num=trp0, val_loss=0.541, traEpoch 13, global step 168: 'val_loss' was not in top 1
# Epoch 14: 100%|█| 12/12 [00:04<00:00,  2.61it/s, v_num=trp0, val_loss=0.541, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.41it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.08it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.39it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.35it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.41it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.28it/s]
# Epoch 14: 100%|█| 12/12 [00:05<00:00,  2.33it/s, v_num=trp0, val_loss=0.536, traEpoch 14, global step 180: 'val_loss' reached 0.53564 (best 0.53564), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=14-step=180.ckpt' as top 1
# Epoch 15: 100%|█| 12/12 [00:04<00:00,  2.56it/s, v_num=trp0, val_loss=0.536, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.59it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.17it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.19it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.30it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.32it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.19it/s]Saved best model 0.5368532793862479 -> 0.5323005403791156
#
# Epoch 15: 100%|█| 12/12 [00:05<00:00,  2.30it/s, v_num=trp0, val_loss=0.536, traEpoch 15, global step 192: 'val_loss' was not in top 1
# Epoch 16: 100%|█| 12/12 [00:04<00:00,  2.62it/s, v_num=trp0, val_loss=0.536, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.51it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.32it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.01it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.32it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.49it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.56it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.32it/s]
# Epoch 16: 100%|█| 12/12 [00:05<00:00,  2.36it/s, v_num=trp0, val_loss=0.540, traEpoch 16, global step 204: 'val_loss' was not in top 1
# Epoch 17: 100%|█| 12/12 [00:04<00:00,  2.60it/s, v_num=trp0, val_loss=0.540, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.97it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.27it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.29it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.22it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.05it/s]Saved best model 0.5323005403791156 -> 0.5292793767792838
#
# Epoch 17: 100%|█| 12/12 [00:05<00:00,  2.32it/s, v_num=trp0, val_loss=0.533, traEpoch 17, global step 216: 'val_loss' reached 0.53262 (best 0.53262), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=17-step=216.ckpt' as top 1
# Epoch 18: 100%|█| 12/12 [00:04<00:00,  2.49it/s, v_num=trp0, val_loss=0.533, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.44it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.68it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.88it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.95it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.12it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.17it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.99it/s]Saved best model 0.5292793767792838 -> 0.5214138329029083
#
# Epoch 18: 100%|█| 12/12 [00:05<00:00,  2.25it/s, v_num=trp0, val_loss=0.527, traEpoch 18, global step 228: 'val_loss' reached 0.52737 (best 0.52737), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=18-step=228.ckpt' as top 1
# Epoch 19: 100%|█| 12/12 [00:04<00:00,  2.53it/s, v_num=trp0, val_loss=0.527, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.56it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.08it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.91it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.89it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.84it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.99it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.83it/s]
# Epoch 19: 100%|█| 12/12 [00:05<00:00,  2.28it/s, v_num=trp0, val_loss=0.532, traEpoch 19, global step 240: 'val_loss' was not in top 1
# Epoch 20: 100%|█| 12/12 [00:04<00:00,  2.61it/s, v_num=trp0, val_loss=0.532, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.05it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.24it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.25it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.12it/s]Saved best model 0.5214138329029083 -> 0.5211691898959023
#
# Epoch 20: 100%|█| 12/12 [00:05<00:00,  2.36it/s, v_num=trp0, val_loss=0.528, traEpoch 20, global step 252: 'val_loss' was not in top 1
# Epoch 21: 100%|█| 12/12 [00:04<00:00,  2.67it/s, v_num=trp0, val_loss=0.528, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.63it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.64it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.52it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.33it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.41it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.37it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.23it/s]Saved best model 0.5211691898959023 -> 0.5162426957062313
#
# Epoch 21: 100%|█| 12/12 [00:05<00:00,  2.38it/s, v_num=trp0, val_loss=0.524, traEpoch 21, global step 264: 'val_loss' reached 0.52433 (best 0.52433), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=21-step=264.ckpt' as top 1
# Epoch 22: 100%|█| 12/12 [00:04<00:00,  2.59it/s, v_num=trp0, val_loss=0.524, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.50it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.50it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.84it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.05it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.09it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.16it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.92it/s]
# Epoch 22: 100%|█| 12/12 [00:05<00:00,  2.34it/s, v_num=trp0, val_loss=0.527, traEpoch 22, global step 276: 'val_loss' was not in top 1
# Epoch 23: 100%|█| 12/12 [00:04<00:00,  2.57it/s, v_num=trp0, val_loss=0.527, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.46it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.70it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.58it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.81it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.85it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.90it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.52it/s]
# Epoch 23: 100%|█| 12/12 [00:05<00:00,  2.29it/s, v_num=trp0, val_loss=0.533, traEpoch 23, global step 288: 'val_loss' was not in top 1
# Epoch 24: 100%|█| 12/12 [00:05<00:00,  2.38it/s, v_num=trp0, val_loss=0.533, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.08it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.84it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.77it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.81it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.90it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.93it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.77it/s]
# Epoch 24: 100%|█| 12/12 [00:05<00:00,  2.16it/s, v_num=trp0, val_loss=0.526, traEpoch 24, global step 300: 'val_loss' was not in top 1
# Epoch 25: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.526, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.19it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.93it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.15it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.10it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.20it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.27it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.07it/s]Saved best model 0.5162426957062313 -> 0.5108942517212459
#
# Epoch 25: 100%|█| 12/12 [00:05<00:00,  2.29it/s, v_num=trp0, val_loss=0.526, traEpoch 25, global step 312: 'val_loss' was not in top 1
# Epoch 26: 100%|█| 12/12 [00:04<00:00,  2.63it/s, v_num=trp0, val_loss=0.526, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.76it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.50it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.43it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.32it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.11it/s]
# Epoch 26: 100%|█| 12/12 [00:05<00:00,  2.37it/s, v_num=trp0, val_loss=0.528, traEpoch 26, global step 324: 'val_loss' was not in top 1
# Epoch 27: 100%|█| 12/12 [00:04<00:00,  2.59it/s, v_num=trp0, val_loss=0.528, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.75it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.59it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.48it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.19it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.03it/s]
# Epoch 27: 100%|█| 12/12 [00:05<00:00,  2.32it/s, v_num=trp0, val_loss=0.527, traEpoch 27, global step 336: 'val_loss' was not in top 1
# Epoch 28: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.527, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.77it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.88it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.79it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.96it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.01it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.09it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.94it/s]
# Epoch 28: 100%|█| 12/12 [00:05<00:00,  2.30it/s, v_num=trp0, val_loss=0.526, traEpoch 28, global step 348: 'val_loss' was not in top 1
# Epoch 29: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.526, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.20it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.05it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.14it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.14it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.02it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.11it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.94it/s]
# Epoch 29: 100%|█| 12/12 [00:05<00:00,  2.30it/s, v_num=trp0, val_loss=0.529, traEpoch 29, global step 360: 'val_loss' was not in top 1
# Epoch 30: 100%|█| 12/12 [00:04<00:00,  2.61it/s, v_num=trp0, val_loss=0.529, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.70it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.68it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.51it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.49it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.35it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.41it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.31it/s]
# Epoch 30: 100%|█| 12/12 [00:05<00:00,  2.37it/s, v_num=trp0, val_loss=0.529, traEpoch 30, global step 372: 'val_loss' was not in top 1
# Epoch 31: 100%|█| 12/12 [00:04<00:00,  2.69it/s, v_num=trp0, val_loss=0.529, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.39it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.30it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.15it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.24it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.36it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.18it/s]
# Epoch 31: 100%|█| 12/12 [00:05<00:00,  2.40it/s, v_num=trp0, val_loss=0.526, traEpoch 31, global step 384: 'val_loss' was not in top 1
# Epoch 32: 100%|█| 12/12 [00:04<00:00,  2.66it/s, v_num=trp0, val_loss=0.526, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.55it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.29it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.09it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.12it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.06it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.70it/s]
# Epoch 32: 100%|█| 12/12 [00:05<00:00,  2.39it/s, v_num=trp0, val_loss=0.527, traEpoch 32, global step 396: 'val_loss' was not in top 1
# Epoch 33: 100%|█| 12/12 [00:04<00:00,  2.46it/s, v_num=trp0, val_loss=0.527, tra
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.71it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.56it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.30it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.36it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.29it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.33it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.15it/s]
# Epoch 33: 100%|█| 12/12 [00:05<00:00,  2.22it/s, v_num=trp0, val_loss=0.524, traEpoch 33, global step 408: 'val_loss' reached 0.52378 (best 0.52378), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=33-step=408.ckpt' as top 1
# Epoch 34: 100%|█| 12/12 [00:04<00:00,  2.59it/s, v_num=trp0, val_loss=0.524, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.30it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.27it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.13it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.22it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.09it/s]Saved best model 0.5108942517212459 -> 0.5098434431212289
#
# Epoch 34: 100%|█| 12/12 [00:05<00:00,  2.33it/s, v_num=trp0, val_loss=0.522, traEpoch 34, global step 420: 'val_loss' reached 0.52175 (best 0.52175), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=34-step=420.ckpt' as top 1
# Epoch 35: 100%|█| 12/12 [00:04<00:00,  2.59it/s, v_num=trp0, val_loss=0.522, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.80it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.14it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.28it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.29it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.31it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.13it/s]
# Epoch 35: 100%|█| 12/12 [00:05<00:00,  2.33it/s, v_num=trp0, val_loss=0.527, traEpoch 35, global step 432: 'val_loss' was not in top 1
# Epoch 36: 100%|█| 12/12 [00:04<00:00,  2.60it/s, v_num=trp0, val_loss=0.527, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.10it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.79it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.02it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.68it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.49it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.58it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.37it/s]Saved best model 0.5098434431212289 -> 0.5044019860880715
#
# Epoch 36: 100%|█| 12/12 [00:05<00:00,  2.33it/s, v_num=trp0, val_loss=0.524, traEpoch 36, global step 444: 'val_loss' was not in top 1
# Epoch 37: 100%|█| 12/12 [00:04<00:00,  2.56it/s, v_num=trp0, val_loss=0.524, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.47it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.21it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.30it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.17it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.23it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.24it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.02it/s]
# Epoch 37: 100%|█| 12/12 [00:05<00:00,  2.30it/s, v_num=trp0, val_loss=0.522, traEpoch 37, global step 456: 'val_loss' reached 0.52173 (best 0.52173), saving model to 'output/wandb_logs/CZII-I/p61ctrp0/checkpoints/epoch=37-step=456.ckpt' as top 1
# Epoch 38: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.522, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.93it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 18.40it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 18.99it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 19.38it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 19.70it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 19.82it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.42it/s]
# Epoch 38: 100%|█| 12/12 [00:05<00:00,  2.28it/s, v_num=trp0, val_loss=0.522, traEpoch 38, global step 468: 'val_loss' was not in top 1
# Epoch 39: 100%|█| 12/12 [00:05<00:00,  2.37it/s, v_num=trp0, val_loss=0.522, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.86it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.62it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.82it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.80it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.81it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.85it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.44it/s]
# Epoch 39: 100%|█| 12/12 [00:05<00:00,  2.13it/s, v_num=trp0, val_loss=0.523, traEpoch 39, global step 480: 'val_loss' was not in top 1
# Epoch 40: 100%|█| 12/12 [00:04<00:00,  2.50it/s, v_num=trp0, val_loss=0.523, tra
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.65it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.56it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.37it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.21it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.22it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.07it/s]
# ...
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.13it/s]
# Epoch 184: 100%|█| 12/12 [00:05<00:00,  2.32it/s, v_num=trp0, val_loss=0.505, trEpoch 184, global step 2220: 'val_loss' was not in top 1
# Epoch 185: 100%|█| 12/12 [00:04<00:00,  2.62it/s, v_num=trp0, val_loss=0.505, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.14it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.10it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.03it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.11it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.17it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.19it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.97it/s]
# Epoch 185: 100%|█| 12/12 [00:05<00:00,  2.36it/s, v_num=trp0, val_loss=0.505, trEpoch 185, global step 2232: 'val_loss' was not in top 1
# Epoch 186: 100%|█| 12/12 [00:04<00:00,  2.57it/s, v_num=trp0, val_loss=0.505, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.67it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.57it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.35it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.38it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.26it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.32it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.17it/s]
# Epoch 186: 100%|█| 12/12 [00:05<00:00,  2.32it/s, v_num=trp0, val_loss=0.505, trEpoch 186, global step 2244: 'val_loss' was not in top 1
# Epoch 187: 100%|█| 12/12 [00:04<00:00,  2.53it/s, v_num=trp0, val_loss=0.505, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.75it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.78it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.89it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.91it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.90it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.01it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.80it/s]
# Epoch 187: 100%|█| 12/12 [00:05<00:00,  2.29it/s, v_num=trp0, val_loss=0.505, trEpoch 187, global step 2256: 'val_loss' was not in top 1
# Epoch 188: 100%|█| 12/12 [00:04<00:00,  2.51it/s, v_num=trp0, val_loss=0.505, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.20it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.79it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.90it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.04it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.06it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.07it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.60it/s]
# Epoch 188: 100%|█| 12/12 [00:05<00:00,  2.27it/s, v_num=trp0, val_loss=0.506, trEpoch 188, global step 2268: 'val_loss' was not in top 1
# Epoch 189: 100%|█| 12/12 [00:04<00:00,  2.41it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.55it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.75it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 19.92it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.09it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.18it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.25it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 22.64it/s]
# Epoch 189: 100%|█| 12/12 [00:05<00:00,  2.15it/s, v_num=trp0, val_loss=0.506, trEpoch 189, global step 2280: 'val_loss' was not in top 1
# Epoch 190: 100%|█| 12/12 [00:05<00:00,  2.34it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.02it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.57it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.69it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.89it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.00it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.09it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.90it/s]
# Epoch 190: 100%|█| 12/12 [00:05<00:00,  2.13it/s, v_num=trp0, val_loss=0.506, trEpoch 190, global step 2292: 'val_loss' was not in top 1
# Epoch 191: 100%|█| 12/12 [00:04<00:00,  2.63it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.04it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.12it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.98it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.10it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.17it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 21.19it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 24.00it/s]
# Epoch 191: 100%|█| 12/12 [00:05<00:00,  2.37it/s, v_num=trp0, val_loss=0.507, trEpoch 191, global step 2304: 'val_loss' was not in top 1
# Epoch 192: 100%|█| 12/12 [00:04<00:00,  2.49it/s, v_num=trp0, val_loss=0.507, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.05it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.88it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.48it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.51it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.64it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.76it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.57it/s]
# Epoch 192: 100%|█| 12/12 [00:05<00:00,  2.25it/s, v_num=trp0, val_loss=0.506, trEpoch 192, global step 2316: 'val_loss' was not in top 1
# Epoch 193: 100%|█| 12/12 [00:04<00:00,  2.47it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.49it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.05it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.81it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.89it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.88it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.74it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.47it/s]
# Epoch 193: 100%|█| 12/12 [00:05<00:00,  2.22it/s, v_num=trp0, val_loss=0.506, trEpoch 193, global step 2328: 'val_loss' was not in top 1
# Epoch 194: 100%|█| 12/12 [00:04<00:00,  2.44it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.53it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 19.76it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.03it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.24it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.42it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.50it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.16it/s]
# Epoch 194: 100%|█| 12/12 [00:05<00:00,  2.21it/s, v_num=trp0, val_loss=0.506, trEpoch 194, global step 2340: 'val_loss' was not in top 1
# Epoch 195: 100%|█| 12/12 [00:04<00:00,  2.46it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.99it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.00it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.89it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.79it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.77it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.62it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.19it/s]
# Epoch 195: 100%|█| 12/12 [00:05<00:00,  2.22it/s, v_num=trp0, val_loss=0.506, trEpoch 195, global step 2352: 'val_loss' was not in top 1
# Epoch 196: 100%|█| 12/12 [00:04<00:00,  2.54it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 19.74it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.07it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.36it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.48it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.62it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.71it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.37it/s]
# Epoch 196: 100%|█| 12/12 [00:05<00:00,  2.29it/s, v_num=trp0, val_loss=0.506, trEpoch 196, global step 2364: 'val_loss' was not in top 1
# Epoch 197: 100%|█| 12/12 [00:04<00:00,  2.51it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 20.18it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.40it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.51it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.63it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.71it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.73it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.40it/s]
# Epoch 197: 100%|█| 12/12 [00:05<00:00,  2.25it/s, v_num=trp0, val_loss=0.506, trEpoch 197, global step 2376: 'val_loss' was not in top 1
# Epoch 198: 100%|█| 12/12 [00:04<00:00,  2.53it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.08it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 20.95it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 21.13it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 21.08it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 21.04it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.99it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.74it/s]
# Epoch 198: 100%|█| 12/12 [00:05<00:00,  2.26it/s, v_num=trp0, val_loss=0.506, trEpoch 198, global step 2388: 'val_loss' was not in top 1
# Epoch 199: 100%|█| 12/12 [00:04<00:00,  2.49it/s, v_num=trp0, val_loss=0.506, tr
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|██▊                 | 1/7 [00:00<00:00, 21.44it/s]
# Validation DataLoader 0:  29%|█████▋              | 2/7 [00:00<00:00, 21.14it/s]
# Validation DataLoader 0:  43%|████████▌           | 3/7 [00:00<00:00, 20.83it/s]
# Validation DataLoader 0:  57%|███████████▍        | 4/7 [00:00<00:00, 20.76it/s]
# Validation DataLoader 0:  71%|██████████████▎     | 5/7 [00:00<00:00, 20.74it/s]
# Validation DataLoader 0:  86%|█████████████████▏  | 6/7 [00:00<00:00, 20.75it/s]
# Validation DataLoader 0: 100%|████████████████████| 7/7 [00:00<00:00, 23.56it/s]
# Epoch 199: 100%|█| 12/12 [00:05<00:00,  2.23it/s, v_num=trp0, val_loss=0.506, trEpoch 199, global step 2400: 'val_loss' was not in top 1
# `Trainer.fit` stopped: `max_steps=2400` reached.
# Epoch 199: 100%|█| 12/12 [00:05<00:00,  2.22it/s, v_num=trp0, val_loss=0.506, tr
# wandb: 🚀 View run 006-1 at: https://wandb.ai/naoya-takashima/CZII-I/runs/p61ctrp0
# wandb: Find logs at: ../../../../../../../../../../../tmp/wandb/run-20241217_030949-p61ctrp0/logs
# Execution successful.
